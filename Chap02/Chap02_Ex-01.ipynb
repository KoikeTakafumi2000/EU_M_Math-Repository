# %% [markdown]
# 1から50までの自然数の和を計算するプログラムを書いて、最後の計算結果を表示するプログラムを書いてくださ
# い。ただし、np.arrayで1から50までの配列を作り、その総和を求める方法で計算してください。

# %%
import numpy as np

# %%
print(np.sum(np.arange(1, 51, 1)))
# Out:
# 1275
