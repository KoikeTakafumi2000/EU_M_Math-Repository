# %% [markdown]
# y = 5x + 3（ は-10から10の値）のグラフを描いてみましょう。

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x):
    return 5*x + 3

# %%
x = np.linspace(-10, 10, 100)
y = f(x)
plt.plot(x, y)
