# %% [markdown]
# 練習問題2-7のデータに対して、以下のデータの同じIDの人をキーとして、データをマージしてください。そして、
# MoneyとMathとEnglishの平均を求めてください。

# %%
from pandas import Series,DataFrame
import pandas as pd

# %%
attri_data1 = {'ID':['1','2','3','4','5'],
'Sex':['F','F','M','M','F'],
'Money':[1000,2000,500,300,700],
'Name':['Saito','Horie','Kondo','Kawada','Matsubara']}

attri_data_frame1 = DataFrame(attri_data1)

# %%
attri_data2 = {'ID':['3','4','7'],
'Math':[60,30,40],
'English':[80,20,30]}
attri_data_frame2 = DataFrame(attri_data2)

# %%
pd.merge(attri_data_frame1,attri_data_frame2,on='ID',how='left')
# Out:
#   ID Sex  Money       Name  Math  English
# 0  1   F   1000      Saito   NaN      NaN
# 1  2   F   2000      Horie   NaN      NaN
# 2  3   M    500      Kondo  60.0     80.0
# 3  4   M    300     Kawada  30.0     20.0
# 4  5   F    700  Matsubara   NaN      NaN
