# %% [markdown]
# 練習問題 2-4と同じ行列について、逆行列、固有値と固有ベクトルを求めてください。

# %%
import numpy as np

# %%
A = np.array([[1, 2, 3],
              [1, 3, 2],
              [3, 2, 1]])

# %%
np.linalg.inv(A)
# Out:
# array([[ 0.08333333, -0.33333333,  0.41666667],
#        [-0.41666667,  0.66666667, -0.08333333],
#        [ 0.58333333, -0.33333333, -0.08333333]])
