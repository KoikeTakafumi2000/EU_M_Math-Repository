# %% [markdown]
# 以下の積分を求めてみましょう。

# %%
import numpy as np
from scipy import integrate

# %%
def f(x):
    return (x + 1) * (x + 1)

# %%
integrate.quad(f, 0, 2)
# Out:
# (8.666666666666668, 9.621932880084691e-14)
