# %% [markdown]
# 2 次元のスプライン補間（点と点の間を2 次の多項式で補間する方法）を使って練習問題 5-10のグラフに書き込ん
# でください（2 次元のスプライン補間はパラメータをquadraticとします）。

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import interpolate

# %%
x = np.linspace(0, 10, num=11, endpoint=True)
y = np.sin(x**2/5.0)
plt.plot(x,y,'o')
plt.grid(True)

# %%
f = interpolate.interp1d(x, y,'linear')
f2 = interpolate.interp1d(x, y,'quadratic')
f3 = interpolate.interp1d(x, y,'cubic')

# %%
x = np.linspace(0, 10, num=11, endpoint=True)
x2 = np.linspace(0, 10, num=100, endpoint=True)
y = np.sin(x**2/5.0)
plt.plot(x,y,'o')
plt.plot(x2,f(x2),'-')
plt.plot(x2,f2(x2),'-.')
# plt.plot(x2,f3(x2),'--')
plt.grid(True)
